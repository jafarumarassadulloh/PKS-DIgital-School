# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here
df = df.dropna()

# Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()
grouped_data = df.groupby('species').mean()

print(grouped_data)
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975
# <ipython-input-4-91a39e4f68cd>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby('species').mean()

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
# Pie plot dari dataset hasil grouping untuk kolom 'flipper_length_mm'
plt.figure(figsize=(8, 6))
grouped_data['flipper_length_mm'].plot(kind='pie', autopct='%1.1f%%')
plt.title("Persentase Flipper Length by Species")
plt.ylabel('')
plt.show()

# Histogram plot dari dataset awal untuk kolom 'body_mass_g'
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='body_mass_g', bins=10, kde=True)
plt.title("Histogram Body Mass")
plt.xlabel("Body Mass (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:

# %% [markdown]
# Berdasarkan pie plot yang menunjukkan persentase flipper length (panjang sirip) berdasarkan spesies penguin, kita dapat melihat beberapa insight sebagai berikut:
#
# 1. Spesies Adelie memiliki proporsi flipper length yang relatif lebih kecil dibandingkan dengan spesies Gentoo dan Chinstrap. Hal ini dapat diindikasikan bahwa penguin spesies Adelie cenderung memiliki panjang sirip yang lebih pendek dibandingkan dengan spesies lainnya.
#
# 2. Spesies Gentoo memiliki proporsi flipper length yang relatif lebih besar dibandingkan dengan spesies lainnya. Ini menunjukkan bahwa penguin spesies Gentoo cenderung memiliki panjang sirip yang lebih panjang dibandingkan dengan spesies lainnya.
#
# 3. Spesies Chinstrap memiliki proporsi flipper length yang berada di antara spesies Adelie dan Gentoo. Hal ini menunjukkan bahwa penguin spesies Chinstrap memiliki panjang sirip yang lebih pendek dibandingkan dengan spesies Gentoo, tetapi lebih panjang dibandingkan dengan spesies Adelie.
#
# Berdasarkan histogram massa tubuh (body mass) dari dataset penguin, kita dapat melihat beberapa insight sebagai berikut:
#
# 1. Distribusi massa tubuh penguin cenderung terkonsentrasi di sekitar rentang nilai tertentu. Ini terlihat dari puncak-puncak atau mode yang terbentuk pada histogram. Massa tubuh penguin lebih umum terdistribusi di sekitar rentang tertentu daripada rentang yang lebih luas.
#
# 2. Terdapat beberapa penguin dengan massa tubuh yang signifikan atau di luar rentang umum. Hal ini dapat dilihat dari ekor panjang pada histogram yang menunjukkan adanya beberapa outlier dengan massa tubuh yang jauh lebih besar daripada penguin-penguin lainnya.
#
# 3. Distribusi massa tubuh penguin cenderung simetris atau mendekati distribusi normal, dengan nilai yang cenderung berpusat di sekitar rata-rata. Namun, perlu diperhatikan bahwa hal ini dapat bervariasi tergantung pada dataset yang digunakan.
#
# Analisis ini memberikan gambaran umum tentang perbandingan panjang sirip (flipper length) antara spesies penguin dan distribusi massa tubuh (body mass) dari dataset penguin secara keseluruhan. Namun, penting untuk dicatat bahwa analisis ini didasarkan pada dataset yang digunakan, dan kesimpulan yang lebih mendalam dapat diperoleh dengan analisis statistik yang lebih detail dan penelitian lebih lanjut terkait faktor-faktor yang mempengaruhi panjang sirip dan massa tubuh penguin.
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here
sns.catplot(data=df, x='sex', y='bill_length_mm', kind='bar')
plt.title('Catplot: Bill Length by Sex')
plt.show()

# Grafik Scatter Plot
sns.scatterplot(data=df, x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm')
plt.title('Scatter Plot: Body Mass vs Flipper Length (Colored by Bill Length)')
plt.show()

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:

# %% [markdown]
# Berdasarkan hasil analisa bivariate dari grafik Catplot dan Scatter Plot yang telah dibuat, berikut adalah beberapa insight yang dapat diperoleh:
#
# 1. Grafik Catplot menunjukkan perbedaan rata-rata panjang paruh (bill length) antara jenis kelamin jantan dan betina pada penguin. Jika terdapat perbedaan yang signifikan antara panjang paruh berdasarkan jenis kelamin, hal ini dapat menunjukkan dimorfisme seksual pada penguin. Misalnya, jika rata-rata panjang paruh jantan lebih besar daripada betina, hal ini dapat menjadi indikasi adanya perbedaan dalam fungsi atau adaptasi yang berkaitan dengan paruh penguin.
#
# 2. Grafik Scatter Plot memperlihatkan hubungan antara massa tubuh (body mass) dan panjang sirip (flipper length) pada sumbu x dan y. Dalam grafik tersebut, warna yang mewakili variasi panjang paruh (bill length) pada titik data dapat memberikan insight tambahan. Dalam konteks ini, kita dapat melihat apakah terdapat pola atau korelasi antara panjang paruh dengan massa tubuh dan panjang sirip penguin. Misalnya, jika terdapat pola di mana penguin dengan panjang paruh tertentu memiliki massa tubuh yang lebih besar atau panjang sirip yang lebih panjang, hal ini dapat menunjukkan adanya keterkaitan antara karakteristik morfologis penguin tersebut.
#
# 3. Dengan memperhatikan kedua grafik, kita dapat melihat adanya variasi yang signifikan dalam panjang paruh, massa tubuh, dan panjang sirip di antara penguin-penguin dalam dataset. Hal ini mengindikasikan adanya diversitas morfologis dalam populasi penguin yang diamati.
#
# Analisis bivariate ini memberikan pemahaman tentang hubungan antara variabel-variabel yang diamati dalam dataset penguin, seperti panjang paruh, massa tubuh, dan panjang sirip. Namun, penting untuk dicatat bahwa insight ini didasarkan pada data yang tersedia dalam dataset yang digunakan. Analisis statistik yang lebih mendalam dan penelitian lebih lanjut dapat diperlukan untuk memahami keterkaitan dan signifikansi dari hubungan yang diamati dalam analisis ini.
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# Hasil analisa dari pairplot multivariate ini dapat memberikan beberapa insight tentang hubungan dan pola antara fitur-fitur dalam dataset. Berikut adalah beberapa hal yang dapat diperoleh dari pairplot:
#
# Korelasi: Pairplot dapat menunjukkan korelasi antara pasangan fitur. Jika dua fitur memiliki pola linear atau hubungan yang terkait, scatter plot pada pairplot akan menunjukkan titik-titik data yang membentuk pola garis atau pola yang mengindikasikan hubungan positif atau negatif antara fitur-fitur tersebut.
#
# Distribusi: Pairplot juga memperlihatkan distribusi dari masing-masing fitur pada diagonal utama. Histogram atau kernel density estimation (KDE) plot dapat memberikan gambaran tentang distribusi data dan apakah data cenderung terkonsentrasi di sekitar nilai tertentu atau memiliki variasi yang luas.
#
# Outlier: Dalam pairplot, kita juga dapat melihat adanya outlier atau titik-titik data yang berada jauh dari pola umum. Outlier dapat memberikan insight tentang observasi yang tidak biasa atau potensial adanya kesalahan dalam data.
#
# Variasi: Pairplot memperlihatkan variasi fitur-fitur dalam dataset. Dengan melihat pola hubungan antara fitur-fitur yang berbeda, kita dapat memperoleh pemahaman tentang variasi dalam dataset dan memperkirakan bagaimana fitur-fitur saling mempengaruhi.
#
# ---
#
#
#
# ---
#
#
#
# ---
