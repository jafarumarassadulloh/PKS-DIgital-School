# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2>Soal 1: Multiple Subplots</h2>
#
# Dengan data di bawah ini buatlah visualisasi seperti expected output:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(2*-np.pi, 2*np.pi, 200)

tan = np.tan(x)/10
cos = np.cos(x)
sin = np.sin(x)

# %%
#code here
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True,figsize=(21,7))
ax[0].plot(x, tan, color = 'blue')
ax[1].plot(x, sin, color = 'red')
ax[2].plot(x, cos, color = 'green')
plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xdrkV37TJk7isPQIjg9gNJ6capaCLYam)

# %% [markdown]
# <h2>Soal 2: Nested Axis</h2>
#
# Dengan data di bawah ini, buatlah visualisasi seperti expected output:

# %%
x = np.linspace(2*-np.pi, 2*np.pi, 100)
y = np.cos(x)
y2 = np.cos(x**2)
y3 = np.cos(x**3)
y4 = np.cos(x**4)
y5 = np.cos(x**5)

# %%
#code here
fig, ax = plt.subplots()

ax.plot(x, y, color = 'blue')

ins1 = ax.inset_axes([0.9, 0.9, 0.3, 0.3])
ins1.plot(x, y5, color = 'black')
ins1.plot(x, y, color = 'blue')

ins2 = ax.inset_axes([-0.1, 0.9, 0.3, 0.3])
ins2.plot(x, y4, color = '#C7C721')
ins2.plot(x, y, color = 'blue')

ins3 = ax.inset_axes([-0.1, -0.1, 0.3, 0.3])
ins3.plot(x, y2, color = 'red')
ins3.plot(x, y, color = 'blue')

ins4 = ax.inset_axes([0.9, -0.1, 0.3, 0.3])
ins4.plot(x, y3, color = 'green')
ins4.plot(x, y, color = 'blue')

plt.show()

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1xIdrYVaafiMdAP59fyMkxZ-qwxapAD_g)
