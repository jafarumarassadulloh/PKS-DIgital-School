# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
fig, ax = plt.subplots()
# memberikan data kedalam axis
plt.title('Grafik Cos Sin')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
ax.plot(x, cos, color='red')
ax.plot(x, cos3, linestyle='--', color='green')
ax.plot(x, sin, linestyle='-.', color='blue')
ax.plot(x, sin2, marker='x',linestyle='',color = '#E4E494')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4ab9ad03bb4> in <cell line: 2>()
#       1 #code here
# ----> 2 fig, ax = plt.subplots()
#       3 # memberikan data kedalam axis
#       4 plt.title('Grafik Cos Sin')
#       5 plt.xlabel('X-axis Label')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
